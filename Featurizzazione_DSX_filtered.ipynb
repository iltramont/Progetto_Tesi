# %%
import numpy as np
import pandas as pd
from SMILES_to_Features import smile_to_feature

# %%
data = pd.read_csv("DSX_filtered.csv")

# %%
data
# Out:
#                                                   smiles
# 0      CCOc1ccc2ccccc2c1C(=O)N[C@@H]1C(=O)N2[C@@H](C(...
# 1      C[C@@H]1C/C=C/C=C/C=C/C=C/[C@H](O[C@@H]2O[C@H]...
# 2      CCC(C)CCCCC(=O)N[C@@H](CCN)C(=O)N[C@H](C(=O)N[...
# 3      CC(C)CC(NC(=O)CNC(=O)C(Cc1ccc(O)cc1)NC(=O)C(CO...
# 4      COC(=O)OC(=O)[C@H]1[C@H]2C[C@@H]3c4[nH]c5cc(OC...
# ...                                                  ...
# 71611  CC(=O)O[C@H]1C[C@@]2(C)[C@@H](C[C@@H](O)[C@H]3...
# 71612  C=CC(=C)C(=O)O[C@H]1[C@H]2[C@](C)(C(=O)[C@H](O...
# 71613  OC[C@H]1O[C@H](O[C@]2(CO[C@]3(CO[C@]4(CO[C@]5(...
# 71614  CO[C@]1(C)C[C@@H](C)C(=O)[C@H](C)[C@H]2N(CCCCn...
# 71615  C[C@H]1OC(CCO[C@H]2[C@@H](O)C[C@H](O[C@H]3CC[C...
#
# [71616 rows x 1 columns]

# %%
df_list = []

# %%
n = 71616
k = 0
for smiles in data["smiles"]:
    try:
        df_list.append(smile_to_feature(smiles))
    except:
        print("lo SMILES di indice " + str(k) + "non funziona")
    k = k + 1
    if k % 1000 == 0:
        percentuale = (100 * k) / n
        print("Percentuale completamento = " + str(percentuale))
# Out:
# Percentuale completamento = 1.3963360142984809
# Percentuale completamento = 2.7926720285969617
# Percentuale completamento = 4.189008042895442
# Percentuale completamento = 5.5853440571939235
# Percentuale completamento = 6.981680071492404
# Percentuale completamento = 8.378016085790884
# Percentuale completamento = 9.774352100089365
# Percentuale completamento = 11.170688114387847
# Percentuale completamento = 12.567024128686327
# Percentuale completamento = 13.963360142984808
# Percentuale completamento = 15.359696157283288
# Percentuale completamento = 16.75603217158177
# Percentuale completamento = 18.15236818588025
# Percentuale completamento = 19.54870420017873
# Percentuale completamento = 20.945040214477213
# Percentuale completamento = 22.341376228775694
# Percentuale completamento = 23.737712243074174
# Percentuale completamento = 25.134048257372655
# Percentuale completamento = 26.530384271671135
# Percentuale completamento = 27.926720285969616
# ...

# %%
df_features_filtered = pd.concat(df_list, ignore_index=True)

# %%
df_features_filtered
# Out:
#        BCUT2D_CHGHI  BCUT2D_CHGLO  BCUT2D_LOGPHI  BCUT2D_LOGPLOW  ...  fr_thiophene  fr_unbrch_alkane  fr_urea       qed
# 0          2.626562     -2.437933       2.506063       -2.700399  ...           0.0               0.0      0.0  0.764417
# 1          2.507799     -2.454595       2.390753       -2.614272  ...           0.0               0.0      0.0  0.177359
# 2          2.381632     -2.287117       2.205033       -2.617260  ...           0.0               1.0      0.0  0.034788
# 3          2.414538     -2.301875       2.240701       -2.603191  ...           0.0               1.0      0.0  0.013004
# 4          2.547764     -2.523789       2.506291       -2.582423  ...           0.0               0.0      0.0  0.273590
# ...             ...           ...            ...             ...  ...           ...               ...      ...       ...
# 74113      2.703602     -2.685275       2.740737       -2.652164  ...           0.0               0.0      0.0  0.185774
# ...

# %%
df_features_filtered.dropna(inplace=True)

# %%
df_features_filtered.reset_index(drop=True, inplace=True)

# %%
df_features_filtered
# Out:
#        BCUT2D_CHGHI  BCUT2D_CHGLO  BCUT2D_LOGPHI  BCUT2D_LOGPLOW  ...  fr_thiophene  fr_unbrch_alkane  fr_urea       qed
# 0          2.626562     -2.437933       2.506063       -2.700399  ...           0.0               0.0      0.0  0.764417
# 1          2.507799     -2.454595       2.390753       -2.614272  ...           0.0               0.0      0.0  0.177359
# 2          2.381632     -2.287117       2.205033       -2.617260  ...           0.0               1.0      0.0  0.034788
# 3          2.414538     -2.301875       2.240701       -2.603191  ...           0.0               1.0      0.0  0.013004
# 4          2.547764     -2.523789       2.506291       -2.582423  ...           0.0               0.0      0.0  0.273590
# ...             ...           ...            ...             ...  ...           ...               ...      ...       ...
# 71886      2.407325     -2.307128       2.264489       -2.611301  ...           0.0               3.0      0.0  0.031000
# ...

# %%
#Salvo il dataset
"""
df_features_filtered.to_csv("feautres_DSX_filtered.csv", index=False)
"""
# Out:
# '\ndf_features_filtered.to_csv("feautres_DSX_filtered.csv", index=False)\n'
